# %%
import numpy as np

# %%
for i in range(1_000_000):
    pass

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ## Introduction to Research
#
# - Research is the research environment
# - Based on .ipynb

# %%
from tqdm import tqdm

for i in tqdm(range(10000000)):
    pass
# Out:
# 100%|██████████| 10000000/10000000 [00:01<00:00, 5595276.08it/s]

# %% [markdown]
# $$ 2x^2 $$

# %%
2+2
# Out:
# 4

# %%
print(2+2)

3+3
# Out:
# 4
# 6

# %%
import numpy as cool_stuff

# %%
cool_stuff.mean([1, 2, 3, 4, 5])
# Out:
# 3.0

# %%
#np.random.normal?

# %%
x = np.random.normal(0, 1, 100)

x
# Out:
# array([-1.22451209,  0.43700578,  0.4539641 ,  0.61036104,  0.3803729 ,
#        -0.06964578,  1.02014233, -1.49703489, -0.46859069, -0.09896942,
#         2.43673748, -0.87024167,  0.48685659, -0.10827108,  1.32024993,
#         0.22825784, -0.58751336,  0.52552433,  0.77142349,  1.07347751,
#         0.15898709, -1.69906694,  0.78363459,  0.96376387, -0.61532419,
#        -1.25289215, -0.004971  , -0.2052844 , -0.03987745,  1.76426377,
#        -0.11193534, -0.46351775,  2.17395092,  1.12925748,  0.8610008 ,
#        -2.56992028, -1.23387537, -0.99839431, -0.1079463 , -1.0665267 ,
#         0.36472678, -0.7064806 ,  0.7429678 ,  0.98877727,  1.92028683,
#        -0.11145905, -0.36544588, -0.48647793, -0.48712027, -1.09890687,
#         1.11028424,  1.57530734,  2.12894566, -0.29537912,  1.51532432,
#         1.5711938 , -0.03475209, -1.56274951,  0.28563062,  0.84278907,
#        -1.43291344, -0.44073512, -0.71447143, -1.54589521,  1.28253328,
# ...

# %% [markdown]
# ### Plotting

# %%
plt.plot(x)

# %%
x = np.random.normal(0, 1, 100)

plt.plot(x)

# %%
x = np.random.normal(0, 1, 10000)

plt.plot(x);

# %%
y = np.random.normal(0, 1, 10000)

# %%
plt.plot(x)
plt.title('Random Normal Distribution of X');

# %%
plt.plot(x, alpha = 0.25)
plt.plot(y, alpha = 0.25)
plt.title('Random Normal Distribution of X and Y');

# %% [markdown]
# ## Adding Axis Labels

# %%
plt.plot(x)
plt.xlabel('X')
plt.title('Why am I doing this?');

# %%
plt.plot(x);

# %%
x = np.random.normal(0, 1, 100)
x2 = np.random.normal(0, 1, 100)

plt.plot(x);
plt.plot(x2);
plt.xlabel('Time')
plt.ylabel('returns')
plt.legend(['X', 'X2']);

# %% [markdown]
# ## Generating Stats

# %%
np.mean(x)
# Out:
# -0.09582638915838486

# %%
np.std(x)
# Out:
# 1.0420331329239205

# %% [markdown]
# ## Getting Real Data
