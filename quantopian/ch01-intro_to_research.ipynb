# %%
import numpy as np

# %%
for i in range(1_000_000):
    pass

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ## Introduction to Research
#
# - Research is the research environment
# - Based on .ipynb

# %%
from tqdm import tqdm

for i in tqdm(range(10000000)):
    pass
# Out:
# 100%|██████████| 10000000/10000000 [00:01<00:00, 5567383.29it/s]

# %% [markdown]
# $$ 2x^2 $$

# %%
2+2
# Out:
# 4

# %%
print(2+2)

3+3
# Out:
# 4
# 6

# %%
import numpy as cool_stuff

# %%
cool_stuff.mean([1, 2, 3, 4, 5])
# Out:
# 3.0

# %%
np.random.normal?

# %%
x = np.random.normal(0, 1, 100)

x
# Out:
# array([ 0.78943579,  0.04262541,  1.23007409,  0.92929658,  0.74111661,
#        -0.2544748 ,  1.49402273,  0.47903359,  0.499194  ,  0.44170541,
#         1.34908966, -0.84516615, -1.55494448, -0.09875544,  0.47507925,
#        -1.53040768, -0.63691391,  0.4902352 ,  2.13232903,  1.27021744,
#         0.50455141, -0.36572537, -0.77476182, -1.73818298, -0.98716188,
#        -2.49298109, -0.26016439,  0.7743891 , -1.91935665,  1.04352172,
#         1.33661689,  0.38727202, -0.49915175,  1.05541984, -1.29095709,
#         1.45746682,  0.74583482, -2.24381531, -0.99552139,  1.88039537,
#         0.19147925,  1.60815938, -0.75613977, -1.48825682, -0.50219003,
#         0.31429352,  0.3385308 ,  0.59683989, -0.87818065,  1.27136256,
#         1.11545723, -1.23243453,  0.4989362 ,  0.10334019,  1.31309215,
#         1.73006923, -1.75553053, -1.50085896, -1.35205173,  0.70648423,
#        -1.26590333, -0.34820134, -0.17427301,  0.08526035,  0.10361709,
#         0.38200982, -0.21400863,  0.97237699,  1.21716539,  0.07108627,
#         0.42482884, -0.51057633, -0.10326555, -0.64252418, -0.25168671,
#         0.24679037,  0.62726984, -1.88206837, -1.22629248, -0.56805444,
#        -0.19861759, -0.20030394, -1.39036336, -0.57104673,  0.4389838 ,
#        -0.3064052 ,  0.26211552,  0.24823619,  0.17673185,  0.50153579,
#         2.32799161, -0.20171937,  0.27343028,  1.04890229, -2.3552995 ,
#         0.85086816,  0.41800115,  1.14300856,  0.62083149, -0.60341317])

# %% [markdown]
# ### Plotting

# %%
plt.plot(x)

# %%
x = np.random.normal(0, 1, 100)

plt.plot(x)

# %%
x = np.random.normal(0, 1, 10000)

plt.plot(x);

# %%
y = np.random.normal(0, 1, 10000)

# %%
plt.plot(x)
plt.title('Random Normal Distribution of X');

# %%
plt.plot(x, alpha = 0.25)
plt.plot(y, alpha = 0.25)
plt.title('Random Normal Distribution of X and Y');

# %% [markdown]
# ## Adding Axis Labels

# %%
plt.plot(x)
plt.xlabel('X')
plt.title('Why am I doing this?');

# %% [markdown]
# ## Getting Real Data
