# %%
import numpy as np

# %%
for i in range(1_000_000):
    pass

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ## Introduction to Research
#
# - Research is the research environment
# - Based on .ipynb

# %%
from tqdm import tqdm

for i in tqdm(range(10000000)):
    pass
# Out:
# 100%|██████████| 10000000/10000000 [00:01<00:00, 5792363.11it/s]

# %% [markdown]
# $$ 2x^2 $$

# %%
2+2
# Out:
# 4

# %%
print(2+2)

3+3
# Out:
# 4
# 6

# %%
import numpy as cool_stuff

# %%
cool_stuff.mean([1, 2, 3, 4, 5])
# Out:
# 3.0

# %%
np.random.normal?

# %%
x = np.random.normal(0, 1, 100)

x
# Out:
# array([ 0.2217598 ,  1.73980113,  0.55299369,  0.35537757,  0.71084667,
#        -0.18193858, -0.37792329,  1.39072787, -0.1392106 , -1.51025943,
#        -1.22517974,  0.47927822,  0.00604832,  1.64470311, -0.74214126,
#         0.93023396,  0.74747157, -0.18572337, -0.7139374 , -1.16949927,
#        -0.33877079,  0.86123206, -0.68229987, -0.12644594,  0.61146744,
#         0.57093866,  1.25776152,  0.415891  ,  0.28095163, -0.24028086,
#         0.40163144, -0.09252475,  0.18170894, -0.10919131,  2.63977471,
#         0.13442777,  0.24706864,  0.25428761,  0.69178687,  0.65094838,
#         1.14474802, -0.05150548, -0.99240661, -0.16313117,  0.49138103,
#         1.23583344, -0.13665895,  1.04300807,  1.11322589,  0.1936142 ,
#         1.35494396, -0.75778967,  0.39738979,  0.99793006,  0.32059926,
#        -0.32216538, -0.05712182, -0.40271204,  0.75777473, -0.02409399,
#        -0.49995546,  2.49296681, -0.5636287 ,  0.0809939 , -0.85000852,
#         0.90161203,  1.03195621,  1.51837971,  0.72971467,  0.71538693,
#        -0.31754947,  0.33162066,  1.83842818,  1.09419021,  0.71874268,
#         1.68762491, -0.50825516,  0.02734843,  1.05230714,  0.38209121,
#        -0.91740386, -0.32313872, -1.0270214 ,  0.30717635,  0.31423883,
#        -0.59109459, -1.06631639,  0.58511691,  0.31762007, -2.37628141,
#        -0.43199852,  0.88142497, -2.57752584,  0.33703728, -0.02144885,
#        -0.05096293,  0.58732267, -1.88700556,  1.90290282, -0.48139199])

# %% [markdown]
# ### Plotting

# %%
plt.plot(x)

# %%
x = np.random.normal(0, 1, 100)

plt.plot(x)

# %%
x = np.random.normal(0, 1, 10000)

plt.plot(x);

# %%
y = np.random.normal(0, 1, 10000)

# %%
plt.plot(x)
plt.title('Random Normal Distribution of X');

# %%
plt.plot(x, alpha = 0.25)
plt.plot(y, alpha = 0.25)
plt.title('Random Normal Distribution of X and Y');

# %% [markdown]
# ## Adding Axis Labels

# %% [markdown]
# ## Getting Real Data
