# %%
import numpy as np

# %%
for i in range(1_000_000):
    pass

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ## Introduction to Research
#
# - Research is the research environment
# - Based on .ipynb

# %%
from tqdm import tqdm

for i in tqdm(range(10000000)):
    pass
# Out:
# 100%|██████████| 10000000/10000000 [00:01<00:00, 5819603.43it/s]

# %% [markdown]
# $$ 2x^2 $$

# %%
2+2
# Out:
# 4

# %%
print(2+2)

3+3
# Out:
# 4
# 6

# %%
import numpy as cool_stuff

# %%
cool_stuff.mean([1, 2, 3, 4, 5])
# Out:
# 3.0

# %%
#np.random.normal?

# %%
x = np.random.normal(0, 1, 100)

x
# Out:
# array([ 0.29010253,  1.34038442,  1.60279623, -0.28486098, -0.09517003,
#         1.63672751, -2.27453132,  0.40000139, -0.74952868,  0.64778041,
#         1.00962559, -0.61386674, -0.54340532, -1.14434562,  0.98894958,
#        -0.34445838, -0.53543262, -0.76287399,  1.49629523, -0.81480075,
#         0.63257497,  1.16761915,  1.15117746, -0.33446592, -0.13338235,
#        -0.6226846 ,  0.11699051,  1.27748529,  0.79034391,  0.02233455,
#        -0.28106344, -0.3135576 , -1.36390308,  0.41494713,  3.23423465,
#        -0.46515004, -0.83539624,  1.52307428, -0.84013799,  0.24450259,
#         0.72875519,  1.13422772, -2.24055564,  1.23362079, -2.27465677,
#        -1.3894701 , -0.14555137, -0.63609783,  0.54625146, -0.65980367,
#         0.32301293,  1.03674882,  0.99252707, -1.86582094, -1.88419443,
#         0.24270419, -0.20761222, -0.51661058, -1.12440413, -0.12282327,
#         0.08891171, -1.97686637,  1.19407788, -2.25170322, -0.24216025,
#        -0.19762034, -0.44565216, -0.76141544, -0.26644752, -1.1640371 ,
#        -0.87071656,  0.10732023, -0.56473054,  0.71284627, -2.12634649,
#         1.52688636, -1.31846976, -2.485898  ,  1.44321105,  1.50956576,
#         0.81258349,  0.71199539, -0.23167295, -1.07805927,  1.41942494,
#         0.2256909 ,  0.71069555,  0.82761317,  0.08830149, -0.56928983,
#        -1.38073427,  0.50068846,  0.60314971, -0.88741019,  0.62023105,
#        -0.94433267, -0.06453635, -0.6293694 ,  1.53089955,  0.18870952])

# %% [markdown]
# ### Plotting

# %%
plt.plot(x)

# %%
x = np.random.normal(0, 1, 100)

plt.plot(x)

# %%
x = np.random.normal(0, 1, 10000)

plt.plot(x);

# %%
y = np.random.normal(0, 1, 10000)

# %%
plt.plot(x)
plt.title('Random Normal Distribution of X');

# %%
plt.plot(x, alpha = 0.25)
plt.plot(y, alpha = 0.25)
plt.title('Random Normal Distribution of X and Y');

# %% [markdown]
# ## Adding Axis Labels

# %%
plt.plot(x)
plt.xlabel('X')
plt.title('Why am I doing this?');

# %%
import sys
sys.path.append("..") # Adds higher directory to python modules path.

# %%
from ..utils import kraken_ex as kex
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-29-76d7a9a25e60> in <module>
# ----> 1 from ..utils import kraken_ex as kex
#
# ImportError: attempted relative import with no known parent package

# %% [markdown]
# ## Getting Real Data
