# %%
import numpy as np

# %%
for i in range(1_000_000):
    pass

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ## Introduction to Research
#
# - Research is the research environment
# - Based on .ipynb

# %%
from tqdm import tqdm

for i in tqdm(range(10000000)):
    pass
# Out:
# 100%|██████████| 10000000/10000000 [00:01<00:00, 5632282.65it/s]

# %% [markdown]
# $$ 2x^2 $$

# %%
2+2
# Out:
# 4

# %%
print(2+2)

3+3
# Out:
# 4
# 6

# %%
import numpy as cool_stuff

# %%
cool_stuff.mean([1, 2, 3, 4, 5])
# Out:
# 3.0

# %%
np.random.normal?

# %%
x = np.random.normal(0, 1, 100)

x
# Out:
# array([-0.85312245,  0.94759782,  0.27994926, -0.84270319,  1.17425558,
#         0.17144244,  1.03892487, -0.5222181 ,  0.89018991, -0.71169736,
#         1.37391748,  1.01353541, -0.72473316, -0.15265198,  0.25033924,
#         0.51016497, -0.36603878,  1.7159853 ,  1.96107556, -0.93525   ,
#         0.28217314, -0.94452082,  0.42572568, -0.32406191,  1.31930857,
#         0.58840687,  1.05051322, -0.1744919 ,  0.19785948, -0.40602552,
#         1.23235542, -0.14156423,  0.63648535, -0.95261221,  0.64985721,
#        -0.65915095, -0.11275866,  0.35178398,  0.75234938,  1.78053233,
#        -0.93136251, -0.03012316,  0.47803065, -0.18052626,  0.41193743,
#         0.01525245, -0.73293757,  0.97960893, -0.60634191,  0.66658629,
#        -0.30091336,  0.07413423,  1.26944133,  1.03615153,  0.2670058 ,
#        -1.01093034,  0.33265309, -2.42551868, -0.60743272,  0.50341373,
#         0.96997913,  0.8215715 , -0.92949452, -0.81441919, -0.78366291,
#         1.03433804,  0.14219611, -1.31187859,  1.0265822 , -2.19009067,
#        -0.01389543, -0.33097533,  0.11154749,  0.05525569,  0.42704294,
#        -0.53250005,  1.18885002,  1.52916308,  0.8540611 ,  1.59568197,
#        -0.39827685, -0.49532168,  1.07601829,  0.17545745,  0.18046934,
#         0.75342673, -2.65095699, -1.15281301, -1.1663471 ,  0.22762311,
#         1.34133788, -0.60776758, -1.09012684,  0.62589116,  0.49220601,
#        -0.41693847,  1.47978322,  0.73260599, -1.03818923, -0.58816162])

# %% [markdown]
# ### Plotting

# %%
plt.plot(x)

# %%
x = np.random.normal(0, 1, 100)

plt.plot(x)

# %%
x = np.random.normal(0, 1, 100)

plt.plot(x);

# %%
plt.plot(x)
plt.title('Random Normal Distribution of X');

# %% [markdown]
# ## Adding Axis Labels

# %% [markdown]
# ## Getting Real Data
